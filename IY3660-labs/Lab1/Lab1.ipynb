# %% [markdown]
# # IY3660 Lab 1
#
# ## Encoding Text to Hexadecimal

# %%
text = "Karma police, arrest this man, he talks in maths"
h = text.encode("utf-8").hex()

print(h)
# Out:
# 4b61726d6120706f6c6963652c206172726573742074686973206d616e2c2068652074616c6b7320696e206d61746873

# %% [markdown]
# ## Bytewise XOR

# %%
n = 0x01
h_int = int(h, 16)
print(hex(h_int^n))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 2
#       1 n = 0x01
# ----> 2 h_int = int(h, 16)
#       3 print(hex(h_int^n))
#
# ValueError: invalid literal for int() with base 16: b'Karma police, arrest this man, he talks in maths'
